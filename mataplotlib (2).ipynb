# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline.

# %%
import numpy as np
x=np.linspace(0,5,11)
y=x**2
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y,'b>')#b is for blue colour and > is for linestyle
plt.xlabel('x axis title')
plt.ylabel('y axis title')
plt.title('chart')
plt.xlim(-5,100)#sets limit for the x axis
plt.ylim(-5,100)#sets limit for the y axis
plt.show()

# %%
''attributes for chart in plt.show()
y axis
x-axis
color
linestyle
marker
''

# %%
TYPE OF MARKER

marker='0'
marker='.'
marker='x'
marker='y'
marker='^'
marker='*'
marker='s'
marker='d'

# %%
import matplotlib.pyplot as plt
#plt.subplot() is used for plotting multple charts in a single plot area
plt.subplot(1,2,1)# parameters for tijs will be rows,columns and chart no
plt.plot(x,y,'b')
plt.subplot(1,2,2)# targets the second chart of the single plot
plt.plot(x,y,'r')
plt.show()

# %%
plt.plot?

# %%
plt.subplot(1,3,1)
plt.plot(x,y,'m.')
plt.xlabel('x axis of subplot1')
plt.ylabel('y axis of subplot1')
plt.xlim(-5,10)
plt.ylim(-5,20)
plt.subplot(1,3,2)
plt.plot(x,y,'m.')
plt.xlabel('x axis of subplot2')
plt.ylabel('y axis of subplot2')
plt.xlim(-10,20)
plt.ylim(-10,20)
plt.subplot(1,3,3)
plt.plot(x,y,'k^')
plt.show()

# %%
#Object oriented approach
#this approach is micer when dealing with a canvas that has multiple plots in it

# %%
#Creates a figure(empty canvas)
fig=plt.figure()
#to add axes
axes=fig.add_axes([0.1,0.1,0.9,0.9])#left,bottom,width,height
axes2=fig.add_axes([0.2,0.5,0.4,0.3])
axes3=fig.add_axes([0.7,0.1,0.3,0.3])

#plot on that set of axesy8
axes.plot(x,y,'r')
axes.set_xlabel('x axis label')
axes.set_ylabel('y axis label')
axes.set_title('set title')

#second chart
axes2.plot(x,y,'g-.')
axes2.set_xlabel('x axis label')
axes2.set_ylabel('y axis label')
axes2.set_title('set title')
# Out:
# Text(0.5, 1.0, 'set title')

# %%
#Scatter Plot
a=np.arange(10)
b=a**2
c1=np.random.randint(0,100,10)#to  make all markers of different colors
plt.scatter(a,b,c=c1,s=100,edgecolor='white',marker='p',linewidth=1.75,cmap='brg',alpha=0.7)# s for size
plt.colorbar()#to show colorbar at on side

# %%
#histogram data
plt.hist(x,y)
# Out:
# (array([1., 1., 3., 3., 3., 0., 0., 0., 0., 0.]),
#  array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#         20.25, 25.  ]),
#  <BarContainer object of 10 artists>)

# %%
from random import sample
data=sample(range(1,1000),100)
plt.hist(data,linewidth=0.6,edgecolor='y')
# Out:
# (array([11., 12., 12.,  8.,  9., 12.,  9., 12.,  5., 10.]),
#  array([ 10. , 107.4, 204.8, 302.2, 399.6, 497. , 594.4, 691.8, 789.2,
#         886.6, 984. ]),
#  <BarContainer object of 10 artists>)

# %%
# stem plot
plt.stem(data)
# Out:
# <StemContainer object of 3 artists>

# %%
plt.stairs(data)

# %%
x=np.arange(0,100,10)
y=np.random.randint(0,100,10)
z=x*2
plt.stackplot(x,y,z)
# Out:
# [<matplotlib.collections.PolyCollection at 0x1bcec9dfcd0>,
#  <matplotlib.collections.PolyCollection at 0x1bcec9f1290>]

# %%
x=[1,2,3,4]
e=(0.4,0,0,0)
plt.pie(x,explode=e,radius=3,center=(4,4),frame=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1bcec719b90>,
#   <matplotlib.patches.Wedge at 0x1bcec71a610>,
#   <matplotlib.patches.Wedge at 0x1bcec71b9d0>,
#   <matplotlib.patches.Wedge at 0x1bcec724e90>],
#  [Text(7.518909104939601, 5.143362895660508, ''),
#   Text(5.019756022668064, 7.1384865228692975, ''),
#   Text(0.8615134293924815, 5.019755875744905, ''),
#   Text(5.019756463437526, 0.861513620345407, '')])

# %%
d=np.random.normal(0,100,60)
#print d
plt.boxplot(d)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bcec77df50>,
#   <matplotlib.lines.Line2D at 0x1bcec79ebd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1bcec79f610>,
#   <matplotlib.lines.Line2D at 0x1bcec79ff90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1bcec79d450>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bcec7acb10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bcec7ac550>],
#  'means': []}

# %%
data=[np.random.normal(0,std,100) for std in range(1,4)]
data1=np.random.normal(0,1,100) 
data2=np.random.normal(0,2,100) 
data3=np.random.normal(0,3,100) 
dataf=[data1,data2,data3]
plt.boxplot(dataf,vert=False,patch_artist=True);

# %%
import matplotlib.pyplot as plt
import numpy as np

x1=np.random.rand(0,50,500)
y1=np.random.rand(0,50,500)
plt.hist2d(x,y,bins=30,cmap='Blues')
plt.colorbar()

# %%
plt.hexbin(x,y,gridsize=30,cmap='Blues')
cb=plt.colorbar(label='count in bin')
